# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
n = 100

x = np.random.random(n)
y = np.random.random(n)

# %%
plt.scatter(x,y,marker='x',c='black')

# %%
m = 1
c = 1
lr = 0.1
iteration = 10000

# %%
for _ in range(iteration):
    y_hat = m*x+c
    error = y_hat-y

    dm = np.mean(error*x)
    dc = np.mean(error)

    m -= lr*dm
    c -= lr*dc

print(f"m : {m}\nc : {c}")
# Out:
# m : 0.04425345010592461
# c : 0.500340696066635

# %%
plt.scatter(x,y,marker='x',c='black')
plt.plot(x,m*x+c, c='red')
